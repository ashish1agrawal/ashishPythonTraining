# %% [markdown]
# <p style="font-family: Arial; font-size:2.75em;color:purple; font-style:bold"><br>
# Demostration of Gradient Descent using R:</p><br>
# <p style="font-family: Arial; font-size:2.25em;color:green; font-style:bold"><br>
# Kumar Rahul</p><br>
#
#
# In this exercise, we will use the German Credit Rating data to demostrate Gradient Descent Algorithm.The Dataset can be dowloaded from:
#
# https://archive.ics.uci.edu/ml/datasets/statlog+(german+credit+data)

# %% [markdown]
# # Code starts here
# We are going to use below mentioned libraries for demonstrating plot the cost function:

# %%
library(ggplot2)

# %% [markdown]
# ## Data Import and Manipulation
#
# ### 1. Import a data set

# %%
raw_data <- read.csv("C:/Users/Administrator/Desktop/Data_Science_with_Python_and_R/Code files/Dataset/german_credit_rating_data 2010.csv", 
                     header = TRUE,sep = ",",na.strings = c(""," ", "NA"))

filter_data <- raw_data
filter_data <- raw_data[complete.cases(raw_data),]
filter_data <- raw_data[,c(-1)]
filter_data
# Out:
#      CHK_ACCT   Duration History         Purpose.of.credit Credit.Amount
# 1    0DM         6        critical        radio-tv          1169
# 2    less-200DM 48        duly-till-now   radio-tv          5951
# 3    no-account 12        critical        education         2096
# 4    0DM        42        duly-till-now   furniture         7882
# 5    0DM        24        delay           new-car           4870
# 6    no-account 36        duly-till-now   education         9055
# 7    no-account 24        duly-till-now   furniture         2835
# 8    less-200DM 36        duly-till-now   used-car          6948
# 9    no-account 12        duly-till-now   radio-tv          3059
# 10   less-200DM 30        critical        new-car           5234
# 11   less-200DM 12        duly-till-now   new-car           1295
# 12   0DM        48        duly-till-now   business          4308
# 13   less-200DM 12        duly-till-now   radio-tv          1567
# 14   0DM        24        critical        new-car           1199
# 15   0DM        15        duly-till-now   new-car           1403
# 16   0DM        24        duly-till-now   radio-tv          1282
# 17   no-account 24        critical        radio-tv          2424
# 18   0DM        30        all-paid-duly   business          8072
# 19   less-200DM 24        duly-till-now   used-car         12579
# 20   no-account 24        duly-till-now   radio-tv          3430
# 21   no-account  9        critical        new-car           2134
# 22   0DM         6        duly-till-now   radio-tv          2647
# 23   0DM        10        critical        new-car           2241
# 24   less-200DM 12        critical        used-car          1804
# 25   no-account 10        critical        furniture         2069
# 26   0DM         6        duly-till-now   furniture         1374
# 27   no-account  6        all-paid-duly   radio-tv           426
# 28   over-200DM 12        bank-paid-duly  radio-tv           409
# 29   less-200DM  7        duly-till-now   radio-tv          2415
# 30   0DM        60        delay           business          6836
# ...  ...        ...      ...             ...               ...
# 971  less-200DM 15        duly-till-now   repairs          1514
# 972  no-account 24        duly-till-now   new-car          7393
# 973  0DM        24        bank-paid-duly  new-car          1193
# 974  0DM        60        duly-till-now   business         7297
# 975  no-account 30        critical        radio-tv         2831
# 976  over-200DM 24        duly-till-now   radio-tv         1258
# 977  less-200DM  6        duly-till-now   radio-tv          753
# 978  less-200DM 18        delay           business         2427
# 979  no-account 24        delay           new-car          2538
# 980  less-200DM 15        bank-paid-duly  new-car          1264
# 981  less-200DM 30        critical        furniture        8386
# 982  no-account 48        duly-till-now   business         4844
# 983  over-200DM 21        duly-till-now   new-car          2923
# 984  0DM        36        duly-till-now   used-car         8229
# 985  no-account 24        critical        furniture        2028
# 986  0DM        15        critical        furniture        1433
# 987  over-200DM 42        all-paid-duly   business         6289
# 988  no-account 13        duly-till-now   radio-tv         1409
# 989  0DM        24        duly-till-now   used-car         6579
# 990  less-200DM 24        critical        radio-tv         1743
# 991  no-account 12        critical        education        3565
# 992  no-account 15        bank-paid-duly  radio-tv         1569
# 993  0DM        18        duly-till-now   radio-tv         1936
# 994  0DM        36        duly-till-now   furniture        3959
# 995  no-account 12        duly-till-now   new-car          2390
# 996  no-account 12        duly-till-now   furniture        1736
# 997  0DM        30        duly-till-now   used-car         3857
# 998  no-account 12        duly-till-now   radio-tv          804
# 999  0DM        45        duly-till-now   radio-tv         1845
# 1000 less-200DM 45        critical        used-car         4576
#      Balance.in.Savings.A.C Employment   Install_rate Marital.status
# 1     unknown                over-seven  4             single-male
# 2     less100DM              four-years  2             female-divorced
# 3     less100DM              seven-years 2             single-male
# 4     less100DM              seven-years 2             single-male
# 5     less100DM              four-years  3             single-male
# 6     unknown                four-years  2             single-male
# 7     less1000DM             over-seven  3             single-male
# 8     less100DM              four-years  2             single-male
# 9     over1000DM             seven-years 2             male-divorced
# 10    less100DM              unemployed  4             married-male
# 11    less100DM              one-year    3             female-divorced
# 12    less100DM              one-year    3             female-divorced
# 13    less100DM              four-years  1             female-divorced
# 14    less100DM              over-seven  4             single-male
# 15    less100DM              four-years  2             female-divorced
# 16    less500DM              four-years  4             female-divorced
# 17    unknown                over-seven  4             single-male
# 18    unknown                one-year    2             single-male
# 19    less100DM              over-seven  4             female-divorced
# 20    less1000DM             over-seven  3             single-male
# 21    less100DM              four-years  4             single-male
# 22    less1000DM             four-years  2             single-male
# 23    less100DM              one-year    1             single-male
# 24    less500DM              one-year    3             single-male
# 25    unknown                four-years  2             married-male
# 26    less100DM              four-years  1             single-male
# 27    less100DM              over-seven  4             married-male
# 28    over1000DM             four-years  3             female-divorced
# 29    less100DM              four-years  3             single-male
# 30    less100DM              over-seven  3             single-male
# ...  ...                    ...          ...          ...
# 971   less500DM              four-years  4             single-male
# 972   less100DM              four-years  1             single-male
# 973   less100DM              unemployed  1             female-divorced
# 974   less100DM              over-seven  4             single-male
# 975   less100DM              four-years  4             female-divorced
# 976   less1000DM             four-years  3             female-divorced
# 977   less100DM              four-years  2             female-divorced
# 978   unknown                over-seven  4             single-male
# 979   less100DM              over-seven  4             single-male
# 980   less500DM              four-years  2             married-male
# 981   less100DM              seven-years 2             single-male
# 982   less100DM              unemployed  3             single-male
# 983   less500DM              four-years  1             female-divorced
# 984   less100DM              four-years  2             single-male
# 985   less100DM              seven-years 2             single-male
# 986   less100DM              four-years  4             female-divorced
# 987   less100DM              one-year    2             male-divorced
# 988   less500DM              unemployed  2             female-divorced
# 989   less100DM              unemployed  4             single-male
# 990   less100DM              over-seven  4             single-male
# 991   unknown                one-year    2             single-male
# 992   less500DM              over-seven  4             single-male
# 993   unknown                seven-years 2             married-male
# 994   less100DM              unemployed  4             single-male
# 995   unknown                over-seven  4             single-male
# 996   less100DM              seven-years 3             female-divorced
# 997   less100DM              four-years  4             male-divorced
# 998   less100DM              over-seven  4             single-male
# 999   less100DM              four-years  4             single-male
# 1000  less500DM              unemployed  3             single-male
#      Co.applicant  ... Real.Estate       Age Other.installment Residence
# 1     none         ...  real-estate      67   none              own
# 2     none         ...  real-estate      22   none              own
# 3     none         ...  real-estate      49   none              own
# 4     guarantor    ...  building-society 45   none              free
# 5     none         ...  none             53   none              free
# 6     none         ...  none             35   none              free
# 7     none         ...  building-society 53   none              own
# 8     none         ...  car              35   none              rent
# 9     none         ...  real-estate      61   none              own
# 10    none         ...  car              28   none              own
# 11    none         ...  car              25   none              rent
# 12    none         ...  building-society 24   none              rent
# 13    none         ...  car              22   none              own
# 14    none         ...  car              60   none              own
# 15    none         ...  car              28   none              rent
# 16    none         ...  car              32   none              own
# 17    none         ...  building-society 53   none              own
# 18    none         ...  car              25   bank              own
# 19    none         ...  none             44   none              free
# 20    none         ...  car              31   none              own
# 21    none         ...  car              48   none              own
# 22    none         ...  real-estate      44   none              rent
# 23    none         ...  real-estate      48   none              rent
# 24    none         ...  building-society 44   none              own
# 25    none         ...  car              26   none              own
# 26    none         ...  real-estate      36   bank              own
# 27    none         ...  car              39   none              own
# 28    none         ...  real-estate      42   none              rent
# 29    guarantor    ...  real-estate      34   none              own
# 30    none         ...  none             63   none              own
# ...  ...               ...               ... ...               ...
# 971   guarantor    ...  real-estate      22   none              own
# 972   none         ...  building-society 43   none              own
# 973   co-applicant ...  none             29   none              rent
# 974   co-applicant ...  none             36   none              rent
# 975   none         ...  car              33   none              own
# 976   none         ...  car              57   none              own
# 977   guarantor    ...  real-estate      64   none              own
# 978   none         ...  building-society 42   none              own
# 979   none         ...  car              47   none              own
# 980   none         ...  building-society 25   none              rent
# 981   none         ...  building-society 49   none              own
# 982   none         ...  car              33   bank              rent
# 983   none         ...  car              28   bank              own
# 984   none         ...  building-society 26   none              own
# 985   none         ...  building-society 30   none              own
# 986   none         ...  building-society 25   none              rent
# 987   none         ...  building-society 33   none              own
# 988   none         ...  real-estate      64   none              own
# 989   none         ...  none             29   none              free
# 990   none         ...  building-society 48   none              own
# 991   none         ...  building-society 37   none              own
# 992   none         ...  car              34   bank              own
# 993   none         ...  car              23   none              rent
# 994   none         ...  building-society 30   none              own
# 995   none         ...  car              50   none              own
# 996   none         ...  real-estate      31   none              own
# 997   none         ...  building-society 40   none              own
# 998   none         ...  car              38   none              own
# 999   none         ...  none             23   none              free
# 1000  none         ...  car              27   none              own
#      Num_Credits Job                      No..dependents Phone Foreign
# 1    2            skilled                 1               no    yes
# 2    1            skilled                 1               yes   yes
# 3    1            unskilled-resident      2               yes   yes
# 4    1            skilled                 2               yes   yes
# 5    2            skilled                 2               yes   yes
# 6    1            unskilled-resident      2               no    yes
# 7    1            skilled                 1               yes   yes
# 8    1            management              1               no    yes
# 9    1            unskilled-resident      1               yes   yes
# 10   2            management              1               yes   yes
# 11   1            skilled                 1               yes   yes
# 12   1            skilled                 1               yes   yes
# 13   1            skilled                 1               no    yes
# 14   2            unskilled-resident      1               yes   yes
# 15   1            skilled                 1               yes   yes
# 16   1            unskilled-resident      1               yes   yes
# 17   2            skilled                 1               yes   yes
# 18   3            skilled                 1               yes   yes
# 19   1            management              1               no    yes
# 20   1            skilled                 2               no    yes
# 21   3            skilled                 1               no    yes
# 22   1            skilled                 2               yes   yes
# 23   2            unskilled-resident      2               yes   no
# 24   1            skilled                 1               yes   yes
# 25   2            skilled                 1               yes   no
# 26   1            unskilled-resident      1               no    yes
# 27   1            unskilled-resident      1               yes   yes
# 28   2            skilled                 1               yes   yes
# 29   1            skilled                 1               yes   yes
# 30   2            skilled                 1               no    yes
# ...  ...         ...                      ...            ...   ...
# 971  1            skilled                 1               yes   yes
# 972  1            unskilled-resident      2               yes   yes
# 973  2            unemployed-non-resident 1               yes   yes
# 974  1            skilled                 1               yes   yes
# 975  1            skilled                 1               no    yes
# 976  1            unskilled-resident      1               yes   yes
# 977  1            skilled                 1               yes   yes
# 978  2            skilled                 1               yes   yes
# 979  2            unskilled-resident      2               yes   yes
# 980  1            skilled                 1               yes   yes
# 981  1            skilled                 1               yes   yes
# 982  1            management              1               no    yes
# 983  1            management              1               no    yes
# 984  1            skilled                 2               yes   yes
# 985  2            unskilled-resident      1               yes   yes
# 986  2            skilled                 1               yes   yes
# 987  2            skilled                 1               yes   yes
# 988  1            skilled                 1               yes   yes
# 989  1            management              1               no    yes
# 990  2            unskilled-resident      1               yes   yes
# 991  2            unskilled-resident      2               yes   yes
# 992  1            unskilled-resident      2               yes   yes
# 993  2            unskilled-resident      1               yes   yes
# 994  1            management              1               no    yes
# 995  1            skilled                 1               no    yes
# 996  1            unskilled-resident      1               yes   yes
# 997  1            management              1               no    yes
# 998  1            skilled                 1               yes   yes
# 999  1            skilled                 1               no    yes
# 1000 1            skilled                 1               yes   yes
#      Credit.classification
# 1     good.
# 2     bad.
# 3     good.
# 4     good.
# 5     bad.
# 6     good.
# 7     good.
# 8     good.
# 9     good.
# 10    bad.
# 11    bad.
# 12    bad.
# 13    good.
# 14    bad.
# 15    good.
# 16    bad.
# 17    good.
# 18    good.
# 19    bad.
# 20    good.
# 21    good.
# 22    good.
# 23    good.
# 24    good.
# 25    good.
# 26    good.
# 27    good.
# 28    good.
# 29    good.
# 30    bad.
# ...  ...
# 971   good.
# 972   good.
# 973   bad.
# 974   bad.
# 975   good.
# 976   good.
# 977   good.
# 978   good.
# 979   bad.
# 980   bad.
# 981   bad.
# 982   bad.
# 983   good.
# 984   bad.
# 985   good.
# 986   good.
# 987   good.
# 988   good.
# 989   good.
# 990   good.
# 991   good.
# 992   good.
# 993   good.
# 994   good.
# 995   good.
# 996   good.
# 997   good.
# 998   good.
# 999   bad.
# 1000  good.

# %% [markdown]
# ### 2. Create dummy variable for factors

# %%
n <- ncol(filter_data)
#for creating X0 variable
processed_data <- cbind(rep(1, nrow(filter_data)))
for (i in 1:n ) {
  if (is.factor(filter_data[,i])) {
    #creating dummies for the factors and storing in temp
    temp <- model.matrix(~filter_data[,i])
    #removing the first column which is an intercept term in dummy coding
    temp <- subset(temp, select = -c(1) )
    #loop through to rename the column names appropriately
      for (c in 1:ncol(temp)) {
        str <- colnames(temp)[c]
        colnames(temp)[c] <- sub("filter_data\\[, i\\]"," ",colnames(temp)[c])
        colnames(temp)[c] <- paste(colnames(filter_data)[i], "- ", colnames(temp)[c])
      }
    #the factors after dummy variable creation is appeneded to the processed_data
    processed_data <- cbind(processed_data,temp)
  }
  #in case not a factor, store the variable in processed_data directly
  else {
    processed_data <- cbind(processed_data,filter_data[,i])
    len <- ncol(processed_data)
    colnames(processed_data)[len] <- colnames(filter_data[i])
    
    #standardize the numeric variable for faster descent. (Feature scaling)
    processed_data[,len] <- scale(processed_data[,len])
  }
}

# %% [markdown]
# ### 3. Seperate x and y variable and converting to matrix form

# %%
x <- processed_data
y <- as.matrix(x[,ncol(x)])
colnames(y)[1] <- colnames(x)[ncol(x)]
x <- x[,c(-ncol(x))]
colnames(x)[1] <- "X0"
x <- as.matrix(x)

# %% [markdown]
# ## Create functions
#
# ### 1. Define Sigmoid function

# %%
sigmoid <- function(z) {
1/(1 + exp(-z))
}

# %% [markdown]
# ### 2. Define Hypothesis function

# %%
hypothesisLr <- function(theta, x) {
sigmoid(x %*% theta) #matrix multiplication (x is 1000*75 and theta is 75*1, result 75*1)
}

# %% [markdown]
# ### 3. Define Cost function

# %%
computeCost <- function(theta, x, y) {
m <- length(y)
s <- sapply(1:m, function(i)
y[i]*log(hypothesisLr(theta,x[i,])) + (1 - y[i])*log(1 - hypothesisLr(theta,x[i,]))
)
j <- -1/m * sum(s)
return(j)
}

# %% [markdown]
# ### 4. Define Gradient Descent function

# %%
gradAlgo <- function(theta, x, y) {
  m <- length(y)
  g <- 1/m * t(x) %*% (hypothesisLr(theta,x) - y)
  return(g)
}

# %% [markdown]
# ## Call functions
#
#
# ### 1. Initialize $\alpha, \theta$ and compute cost
#
# Run normal gradient descent to compute theta and cost function J for each iteration

# %%
alpha <- .3 #learning rate 1
iter <- 1000 #no of interations for descent 5000
#m <- length(y)
theta <- rep(0, ncol(x))

#cost at intial theta
computeCost(theta, x, y)
j <- rep(0,iter) #to maintain log of cost
for (c in 1:iter) {
  theta <- theta - alpha * gradAlgo(theta,x,y)
  j[c] <- computeCost(theta,x,y)
}
# Out:
# [1] 0.6931472

# %% [markdown]
# ### 2. Plot Cost Value
#
# Plot cost as a function of no of iterations to converge

# %%
ggplot() +
  aes(x = 1:iter, y = j) +
  geom_point(colour = "red") +
  geom_path() + xlab("Iteration") +
  ylab("Cost J")
# Out:
# plot without title

# %% [markdown]
# ### 3. Build Classfication matrix

# %%
m <- nrow(y)
actual_y <- y
actual_y[actual_y == 0] <- "Bad"
actual_y[actual_y == 1] <- "Good"
predicted_y = rep("Bad", m);
predicted_y[hypothesisLr(theta,x) >= 0.5] = "Good";
addmargins(table(actual_y, predicted_y))
# Out:
#         predicted_y
# actual_y Bad Good Sum
#     Bad  155 145   300
#     Good  74 626   700
#     Sum  229 771  1000

# %% [markdown]
# ### 4. Score new cases
#
# Scoring new profile pass all X's

# %%
#new_score <- (sigmoid(c(1,<all X's>) %*% theta))

# %% [markdown]
# ## Compare the Gradient Descent with GLM

# %%
lg_glm <- glm(filter_data$Credit.classification ~ .,data = filter_data, family = "binomial")
summary(lg_glm)
lg_predict_prob <- predict(lg_glm, filter_data[,1:20],"response")
m <- length(filter_data[,21])
actual_y <- filter_data[,21]

predicted_y = rep("Bad", m);
predicted_y[lg_predict_prob >= 0.5] = "Good";
addmargins(table(actual_y, predicted_y))
# Out:
# Call:
# glm(formula = filter_data$Credit.classification ~ ., family = "binomial",
#     data = filter_data)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.6116  -0.7095   0.3752   0.6994   2.3410
#
# Coefficients:
#                                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)                        2.353e+00  1.330e+00   1.769 0.076938 .
# CHK_ACCTless-200DM                 3.749e-01  2.179e-01   1.720 0.085400 .
# CHK_ACCTno-account                 1.712e+00  2.322e-01   7.373 1.66e-13 ***
# CHK_ACCTover-200DM                 9.657e-01  3.692e-01   2.616 0.008905 **
# Duration                          -2.786e-02  9.296e-03  -2.997 0.002724 **
# History bank-paid-duly            -1.434e-01  5.489e-01  -0.261 0.793921
# History critical                   1.436e+00  4.399e-01   3.264 0.001099 **
# History delay                      8.532e-01  4.717e-01   1.809 0.070470 .
# History duly-till-now              5.861e-01  4.305e-01   1.362 0.173348
# Purpose.of.credit domestic-app    -2.173e-01  8.041e-01  -0.270 0.786976
# Purpose.of.credit education       -7.764e-01  4.660e-01  -1.666 0.095718 .
# Purpose.of.credit furniture        5.152e-02  3.543e-01   0.145 0.884391
# Purpose.of.credit new-car         -7.401e-01  3.339e-01  -2.216 0.026668 *
# Purpose.of.credit others           7.487e-01  7.998e-01   0.936 0.349202
# Purpose.of.credit radio-tv         1.515e-01  3.370e-01   0.450 0.653002
# Purpose.of.credit repairs         -5.237e-01  5.933e-01  -0.883 0.377428
# Purpose.of.credit retraining       1.319e+00  1.233e+00   1.070 0.284625
# Purpose.of.credit used-car         9.264e-01  4.409e-01   2.101 0.035645 *
# Credit.Amount                     -1.283e-04  4.444e-05  -2.887 0.003894 **
# Balance.in.Savings.A.C less100DM  -3.761e-01  4.011e-01  -0.938 0.348476
# Balance.in.Savings.A.C less500DM  -1.833e-02  4.656e-01  -0.039 0.968595
# Balance.in.Savings.A.C over1000DM  9.631e-01  6.425e-01   1.499 0.133868
# Balance.in.Savings.A.C unknown     5.706e-01  4.492e-01   1.270 0.203940
# Employment one-year               -1.159e-01  2.423e-01  -0.478 0.632415
# Employment over-seven              9.379e-02  2.510e-01   0.374 0.708653
# Employment seven-years             6.482e-01  2.684e-01   2.415 0.015734 *
# Employment unemployed             -1.828e-01  4.105e-01  -0.445 0.656049
# Install_rate                      -3.301e-01  8.828e-02  -3.739 0.000185 ***
# Marital.status male-divorced      -2.755e-01  3.865e-01  -0.713 0.476040
# Marital.status married-male        9.162e-02  3.118e-01   0.294 0.768908
# Marital.status single-male         5.406e-01  2.102e-01   2.572 0.010113 *
# Co.applicant guarantor             1.415e+00  5.685e-01   2.488 0.012834 *
# Co.applicant none                  4.360e-01  4.101e-01   1.063 0.287700
# Present.Resident                  -4.776e-03  8.641e-02  -0.055 0.955920
# Real.Estate car                    8.690e-02  2.313e-01   0.376 0.707115
# Real.Estate none                  -4.490e-01  4.130e-01  -1.087 0.277005
# Real.Estate real-estate            2.814e-01  2.534e-01   1.111 0.266630
# Age                                1.454e-02  9.222e-03   1.576 0.114982
# Other.installment none             6.463e-01  2.391e-01   2.703 0.006871 **
# Other.installment stores           1.232e-01  4.119e-01   0.299 0.764878
# Residence own                     -2.402e-01  4.503e-01  -0.534 0.593687
# Residence rent                    -6.839e-01  4.770e-01  -1.434 0.151657
# Num_Credits                       -2.721e-01  1.895e-01  -1.436 0.151109
# Job skilled                       -7.524e-02  2.845e-01  -0.264 0.791419
# Job unemployed-non-resident        4.795e-01  6.623e-01   0.724 0.469086
# Job unskilled-resident            -5.666e-02  3.501e-01  -0.162 0.871450
# No..dependents                    -2.647e-01  2.492e-01  -1.062 0.288249
# Phone yes                         -3.000e-01  2.013e-01  -1.491 0.136060
# Foreign yes                       -1.392e+00  6.258e-01  -2.225 0.026095 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# (Dispersion parameter for binomial family taken to be 1)
#
#     Null deviance: 1221.73  on 999  degrees of freedom
# Residual deviance:  895.82  on 951  degrees of freedom
# AIC: 993.82
#
# Number of Fisher Scoring iterations: 5
#         predicted_y
# actual_y Bad Good Sum
#    bad.  160 140   300
#    good.  74 626   700
#   Sum    234 766  1000

# %% [markdown]
# #### End of Document
#
# ***
# ***
